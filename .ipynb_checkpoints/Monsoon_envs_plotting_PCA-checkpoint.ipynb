# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import math
import operator
# %matplotlib inline
from __future__ import division
from matplotlib.mlab import PCA as mlabPCA
cm = plt.get_cmap('gist_rainbow')

# %%
final_df = pd.read_csv("full_envars.csv", index_col = 0)

# %%
final_df['EMH']
# Out:
# GL0    0.739856
# GL1    1.806638
# GL2    1.957909
# GL3    1.778625
# GL4    0.416255
# PJ0    1.247304
# PJ1    1.249905
# PJ2    3.743948
# PJ3    1.297391
# PJ4    1.540871
# PP0    4.595257
# PP1    2.599399
# PP2    5.950154
# PP3    2.319062
# PP4    2.419027
# Name: EMH, dtype: float64

# %%
def polyfit(x, y, degree):
    results = {}
#     x = x[~np.isnan(y)] 
#     y = y[~np.isnan(y)]

    coeffs = np.polyfit(x, y, degree)
    
    # Polynomial Coefficients
    results['polynomial'] = coeffs.tolist()

    # r-squared
    p = np.poly1d(coeffs)
    # fit values, and mean
    yhat = p(x)                         # or [p(z) for z in x]
    ybar = np.sum(y)/len(y)          # or sum(y)/len(y)
    ssreg = np.sum((yhat-ybar)**2)   # or sum([ (yihat - ybar)**2 for yihat in yhat])
    sstot = np.sum((y - ybar)**2)    # or sum([ (yi - ybar)**2 for yi in y])
    results['determination'] = ssreg / sstot

    return results

# %%
def make_plot(new_y, new_x, title, label, color, count):

    r = math.floor(count/2)
    if count % 2 == 0:
        c = 0
    else:
        c = 1
    
#     yrange = np.amax(new_y) - np.amin(new_y)
    axs[r,c].set_title(title, fontsize = 14, fontweight='bold')
#     axs[r,c].set_xlabel(predictors[i])
#     axs[r,c].set_ylabel(responses[z])
    #Delta label
    axs[r,c].set_xlabel(ur'$\u0394$' + predictors[i])
    axs[r,c].set_ylabel(ur'$\u0394$' + responses[z])
    axs[r,c].scatter(new_x, new_y, color=color)
#     axs[r,c].set_ylim(np.amin(new_y)-0.25*yrange, np.amax(new_y)+0.25*yrange)
#     axs[r,c].set_xlim(np.amin(new_x)-0.15*np.amax(new_x), np.amax(new_x)+0.15*np.amax(new_x))


    xs = np.linspace(np.amin(new_x), np.amax(new_x), 101)
    ys = p(xs)            
    axs[r,c].plot(xs, ys, color=color, label = the_label, lw = 2)
    axs[r,c].legend(bbox_to_anchor=(1, 1), loc = 2)
    axs[r,c].autoscale_view(True,True,True)
    axs[r,c].autoscale(True,axis = 'both')
    count += 1
    
    return count

# %%
# predictors =['Time', 'SolarMax_1','SolarMax_3','SolarMax_30','SolarMax_7','AirTempMax_1', 'AirTempMax_3', 'AirTempMax_30', 'AirTempMax_7', 'AirTempMin_1', 'AirTempMin_3', 'AirTempMin_30', 'AirTempMin_7', 'AirTemp_1', 'AirTemp_3', 'AirTemp_30', 'AirTemp_7', 'Evapo_1', 'Evapo_3', 'Evapo_30', 'Evapo_7', 'Precip_1', 'Precip_3', 'Precip_30', 'Precip_7', 'SWC_1', 'SWC_3', 'SWC_30', 'SWC_7', 'Stemp_1', 'Stemp_3', 'Stemp_30', 'Stemp_7']
predictors =['Time', 'SolarMax_3', 'AirTempMax_3', 'AirTempMin_3']
# responses =  ['betaSIM', 'Observed_Species', 'Shannon', 'Evenness', 'EMH_m', 'SEMH_m', 'LEMH_m', 'NonAM_m', 'EMH', 'SEMH', 'LEMH', 'NonAM']
responses =  ['betaSIM', 'Shannon', 'Evenness', 'EMH', 'EMH_m']

# %%
print len(responses)*len(predictors)*4
# Out:
# 80

# %%
final_df.columns.values
# Out:
# array(['Time', 'NMDS1', 'betaSIM', 'Observed_Species', 'Shannon',
#        'Evenness', 'SolarMax_1', 'SolarMax_3', 'SolarMax_30', 'SolarMax_7',
#        'AirTempMax_1', 'AirTempMax_3', 'AirTempMax_30', 'AirTempMax_7',
#        'AirTempMin_1', 'AirTempMin_3', 'AirTempMin_30', 'AirTempMin_7',
#        'AirTemp_1', 'AirTemp_3', 'AirTemp_30', 'AirTemp_7', 'Evapo_1',
#        'Evapo_3', 'Evapo_30', 'Evapo_7', 'Precip_1', 'Precip_3',
#        'Precip_30', 'Precip_7', 'SWC_1', 'SWC_3', 'SWC_30', 'SWC_7',
#        'Stemp_1', 'Stemp_3', 'Stemp_30', 'Stemp_7', 'EMH_m', 'SEMH_m',
#        'LEMH_m', 'NonAM_m', 'EMH', 'SEMH', 'LEMH', 'NonAM'], dtype=object)

# %%
pca_df = final_df[['SolarMax_3','SWC_3','AirTemp_3']]

# %%
mlab_pca = mlabPCA(pca_df,standardize=True)

# %%
mlab_pca.fracs*100
# Out:
# array([ 66.86343941,  18.18373947,  14.95282112])

# %%
mlab_pca.Wt
# Out:
# array([[-0.57806579,  0.56066863, -0.59286646],
#        [ 0.56573012,  0.79896585,  0.20396813],
#        [-0.58803859,  0.21749542,  0.77904195]])

# %%
for i in range(len(mlab_pca.Wt)):
    print str(round(mlab_pca.Wt[0][i], 2)) + ' x ' + pca_df.columns.values[i]
# Out:
# -0.58 x SolarMax_3
# 0.56 x SWC_3
# -0.59 x AirTemp_3

# %%
response = 'NMDS1'
pca_y = []
value = 0

df = pd.DataFrame(final_df[response][np.isfinite(final_df[response])].copy())
df.columns = ['X']
for i in range(len(df)):
    for j in range(len(mlab_pca.Wt[0])):
        value += mlab_pca.Wt[0][j]*(df['X'][i])
    pca_y.append(value)

df['Site'] = df.index
df['Y'] = pca_y
GL = df[df['Site'].str.contains('G')]
PJ = df[df['Site'].str.contains('PJ')]
PP = df[df['Site'].str.contains('PP')]

fig, ax = plt.subplots()
ax.set_xlabel(response)
ax.set_ylabel('PCA1')

plt.scatter(GL['X'],GL['Y'], color = 'red')
for i, txt in enumerate(list(GL.index)):
    ax.annotate(txt, (GL['X'][i],GL['Y'][i]))

fig, ax = plt.subplots()
ax.set_xlabel(response)
ax.set_ylabel('PCA1')

ax.scatter(PJ['X'],PJ['Y'], color = 'green')
for i, txt in enumerate(list(PJ.index)):
    ax.annotate(txt, (PJ['X'][i],PJ['Y'][i]))

fig, ax = plt.subplots()
ax.set_xlabel(response)
ax.set_ylabel('PCA1')

ax.scatter(PP['X'],PP['Y'], color = 'blue')
for i, txt in enumerate(list(PP.index)):
    ax.annotate(txt, (PP['X'][i],PP['Y'][i]))

# %%
pca_y
# Out:
# [0.93821928576188118,
#  1.4642054978069998,
#  2.1314677373361013,
#  2.560788192346823,
#  3.012566348486748,
#  3.1479838452413738,
#  2.9483666159108735,
#  2.8831904615467723,
#  2.7979366341622698,
#  2.8463915654029965,
#  2.1527659375917865,
#  1.2197338925798573,
#  0.74147029543429588,
#  -0.00012205272352783236]

# %%
plfa_df = pd.read_csv('Bact_PLFA.csv', skiprows = 3, index_col = 0)

# %%
plfa_df
# Out:
#               C14      a150      i150      C150      i160      C160   10me160  \
# GLsetup  0.353960  1.537500  1.185938  0.223462  0.827357  3.813644  3.061160
# PJsetup  0.300743  0.839063  0.880078  0.162624  0.510166  1.865779  1.380316
# PPsetup  0.341584  1.083984  1.054688  0.177833  0.089834  1.801442  0.745518
# GLH1     0.210396  0.778125  0.822656  0.160284  0.646580  2.338325  1.579613
# PJH1     0.290842  1.101562  1.133203  0.169644  0.748614  2.201886  2.058348
# PPH1     0.278465  1.389844  1.523438  0.215272  0.900555  2.748752  1.306503
# GLCH2    0.211634  0.595313  0.642188  0.143905  0.513494  1.580699  1.143058
# PJCH2    0.248762  0.977344  0.965625  0.160284  0.623290  2.587909  2.071002
# PPCH2    0.409653  2.163281  2.302734  0.299509  1.453974  4.166389  1.716696
# GLCH3    0.268564  1.279688  1.335938  0.190703  0.920518  2.828619  2.106854
# PJCH3    0.389851  1.673437  1.717969  0.233991  1.055823  3.912368  2.768014
# PPCH3    0.129950  0.384375  0.377344  0.101786  0.390388  1.422074  1.438313
# GLCH4    0.183168  0.582422  0.543750  0.133375  0.344917  1.500832  1.066081
# PJCH4    0.290842  0.884766  0.904687  0.156774  0.505730  2.103161  1.512127
# PPCH4    0.274752  1.282031  1.255078  0.179003  0.712015  1.862451  1.013357
# GLPH2    0.216584  0.863672  0.830859  0.170814  0.679852  2.556850  1.992970
# PJPH2    0.285891  1.112109  1.080469  0.182513  0.735305  2.489185  1.775747
# PPPH2    0.384901  1.757812  1.689844  0.228141  0.924954  2.850804  1.228471
# GLPH3    0.301980  1.239844  1.419141  0.198892  0.933826  3.273433  2.636204
# PJPH3    0.405941  0.855469  0.992578  0.166134  0.547874  2.005546  1.368717
# PPPH3    0.346535  1.439062  1.624219  0.210592  0.904991  2.602329  1.550088
# GLPH4    0.264851  0.829688  0.851953  0.166134  0.669871  3.046034  2.444288
# PJPH4    0.231436  0.533203  0.578906  0.127525  0.058780  1.272324  0.904745
# PPPH4    0.377475  1.351172  1.401563  0.216442  0.920518  2.596783  1.355009
# GLMH2    0.123762  0.533203  0.513281  0.209422  0.206285  0.915141  0.515641
# GLMH3    0.141089  0.716016  0.802734  0.100616  0.235120  1.031614  0.628471
# GLMH4    0.123762  0.557813  0.799219  0.217612  0.216266  0.920688  0.570475
# PJMH2    0.165842  0.782813  0.578906  0.122845  0.302773  1.209096  0.988049
# PJMH3    0.000000  0.962109  0.708984  0.109976  0.329390  1.200222  0.946924
# PJMH4    0.137376  0.717187  0.607031  0.218782  0.261738  1.072657  0.485062
# PPMH2    0.170792  0.978516  0.868359  0.126355  0.461368  1.491958  0.572583
# PPMH3    0.141089  0.761719  0.639844  0.218782  0.247320  1.020521  0.517750
# PPMH4    0.121287  0.529687  0.501563  0.205912  0.170795  0.826400  0.410193
#
#           C161w7c      C170     cy170      C180   C181w7c   C181n9t   C181n9c  \
# GLsetup  2.582463  0.286108  1.274958  0.727537  3.695234  0.183920  3.634524
# PJsetup  2.344030  0.201170  0.622188  0.455640  1.553172  0.117588  1.625013
# PPsetup  1.839179  0.193346  0.692843  0.469447  1.950825  0.260302  1.966002
# GLH1     2.308209  0.211228  1.088301  0.464137  1.328544  0.162814  1.845593
# PJH1     2.059701  0.242521  0.390186  0.509807  1.326520  0.222111  1.721137
# PPH1     2.104478  0.253697  0.752953  0.757275  2.089447  0.246231  3.369422
# GLCH2    1.366791  0.185523  0.781426  0.370672  0.961247  0.191960  1.351816
# PJCH2    1.878358  0.248109  0.647497  0.585216  1.914398  0.175879  1.825357
# PPCH2    3.072761  0.364341  1.136811  1.042980  3.785288  0.372864  4.171810
# GLCH3    1.125000  0.250345  0.946991  0.607520  1.908327  0.194975  2.400081
# PJCH3    2.771642  0.311813  0.912191  0.787014  2.532632  0.232161  3.000101
# PPCH3    1.416045  0.139701  0.365931  0.275083  0.628352  0.112563  1.194981
# GLCH4    1.356716  0.173230  0.610588  0.357927  0.901548  0.099497  1.157543
# PJCH4    3.233955  0.224640  0.703389  0.492813  1.596681  0.177889  1.900233
# PPCH4    1.604104  0.210111  0.693898  0.463074  1.605788  0.183920  1.863807
# GLPH2    3.019030  0.233580  1.138920  0.520428  1.691794  0.141709  2.112719
# PJPH2    2.215299  0.243639  0.655934  0.592650  1.742386  0.193970  1.809167
# PPPH2    1.955597  0.268226  0.765607  0.694612  2.683396  0.325628  2.365678
# GLPH3    2.365299  0.273814  1.085138  0.674432  2.228068  0.180905  2.559951
# PJPH3    1.773134  0.215699  0.604260  0.483254  1.487403  0.155779  1.648285
# PPPH3    4.046642  0.258168  0.640115  0.640445  2.107660  0.218090  2.324193
# GLPH4    3.247388  0.233580  1.350886  0.550166  1.977132  0.139698  2.335323
# PJPH4    1.301866  0.166524  0.565242  0.344120  0.856015  0.270352  1.086715
# PPPH4    2.087687  0.246992  0.786699  0.620265  1.903268  0.311558  2.537691
# GLMH2    0.952612  0.102820  0.395458  0.274021  0.430031  0.166834  0.500860
# GLMH3    1.908582  0.110643  1.071429  0.305884  1.076596  0.123618  1.624001
# GLMH4    0.904478  0.106173  0.368040  0.276145  0.520085  0.096482  0.613174
# PJMH2    1.213433  0.125172  0.420768  0.329250  0.723465  0.097487  0.746737
# PJMH3    1.283955  0.122937  0.375422  0.317567  0.587878  0.083417  0.699180
# PJMH4    0.921269  0.113996  0.321639  0.288890  0.423960  0.079397  0.553476
# PPMH2    0.955970  0.145289  0.422877  0.403597  0.746737  0.106533  0.855004
# PPMH3    0.636940  0.109526  0.304767  0.291015  0.483659  0.082412  0.541334
# PPMH4    0.644776  0.098350  0.305821  0.261276  0.424972  0.087437  0.474552
#
#             cy190
# GLsetup  1.250427
# PJsetup  1.139643
# PPsetup  1.264788
# GLH1     1.004240
# PJH1     1.648431
# PPH1     1.652534
# GLCH2    0.622649
# PJCH2    1.621760
# PPCH2    2.176708
# GLCH3    1.338645
# PJCH3    1.843329
# PPCH3    0.629830
# GLCH4    0.635984
# PJCH4    1.329413
# PPCH4    1.299665
# GLPH2    1.040142
# PJPH2    1.577652
# PPPH2    1.697668
# GLPH3    1.417630
# PJPH3    1.299665
# PPPH3    1.890515
# GLPH4    1.073993
# PJPH4    0.881146
# PPPH4    1.421733
# GLMH2    0.501607
# GLMH3    0.599056
# GLMH4    0.475963
# PJMH2    0.610340
# PJMH3    0.603159
# PJMH4    0.502633
# PPMH2    0.759078
# PPMH3    0.533406
# PPMH4    0.467756

# %%
mlab_pca = mlabPCA(plfa_df,standardize=True)

# %%
# Out:
# 33

# %%
plt.plot(mlab_pca.Y[1],mlab_pca.Y[2], 'o', markersize=7,\
        color='blue', alpha=0.5)

plt.xlabel('x_values')
plt.ylabel('y_values')
plt.title('Transformed samples with class labels from matplotlib.mlab.PCA()')
plt.show()
