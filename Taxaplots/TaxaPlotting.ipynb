# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tax_df = pd.read_csv('table_mc3275_sorted_L4.txt', sep = '\t')

# %%
tax_df
# Out:
#                                                 Taxon     GLCH2     GLCH3  \
# 0                      Unclassified;Other;Other;Other  0.012563  0.031309
# 1                          k__Fungi;Other;Other;Other  0.007494  0.022132
# 2                  k__Fungi;p__Ascomycota;Other;Other  0.013886  0.015115
# 3     k__Fungi;p__Ascomycota;c__Dothideomycetes;Other  0.011902  0.049123
# 4   k__Fungi;p__Ascomycota;c__Dothideomycetes;o__B...  0.000000  0.000000
# 5   k__Fungi;p__Ascomycota;c__Dothideomycetes;o__C...  0.007714  0.006208
# 6   k__Fungi;p__Ascomycota;c__Dothideomycetes;o__D...  0.020278  0.099055
# 7   k__Fungi;p__Ascomycota;c__Dothideomycetes;o__H...  0.000000  0.000000
# 8   k__Fungi;p__Ascomycota;c__Dothideomycetes;o__I...  0.003527  0.017274
# 9   k__Fungi;p__Ascomycota;c__Dothideomycetes;o__P...  0.298215  0.231039
# 10  k__Fungi;p__Ascomycota;c__Dothideomycetes;o__u...  0.002865  0.001080
# 11     k__Fungi;p__Ascomycota;c__Eurotiomycetes;Other  0.000000  0.003779
# ...
